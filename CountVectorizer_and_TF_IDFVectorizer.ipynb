# %% [markdown]
# <a href="https://colab.research.google.com/github/sparshap95-tech/NLP/blob/main/CountVectorizer_and_TF_IDFVectorizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

# %%
Sentence=["i love ai"]

# %%
# create object
cv = CountVectorizer()

# %%
# fit and transform
X = cv.fit_transform(Sentence)

# %%
# convert to array
print(X.toarray())
# Out:
# [[1 1]]

# %%
# vocabulary (important)
print(cv.get_feature_names_out())
# Out:
# ['ai' 'love']

# %% [markdown]
# TF-IDF Vectorizer
#
# 👉 Converts text → importance-based numbers

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

sentences = ["I love AI", "I love coding"]

tfidf = TfidfVectorizer()

X = tfidf.fit_transform(sentences)

print(X.toarray())
print(tfidf.get_feature_names_out())
# Out:
# [[0.81480247 0.         0.57973867]
#  [0.         0.81480247 0.57973867]]
# ['ai' 'coding' 'love']
